# %%
pip install pymongo
# Out:
# ...
#   Using cached pymongo-4.6.1-cp310-cp310-win_amd64.whl.metadata (22 kB)
# ...
#   Using cached dnspython-2.5.0-py3-none-any.whl.metadata (5.8 kB)
# ...
#    ---------------------------------------- 0.0/472.7 kB ? eta -:--:--
#     --------------------------------------- 10.2/472.7 kB ? eta -:--:--
#     --------------------------------------- 10.2/472.7 kB ? eta -:--:--
#     --------------------------------------- 10.2/472.7 kB ? eta -:--:--
#     --------------------------------------- 10.2/472.7 kB ? eta -:--:--
#     --------------------------------------- 10.2/472.7 kB ? eta -:--:--
#     --------------------------------------- 10.2/472.7 kB ? eta -:--:--
#     --------------------------------------- 10.2/472.7 kB ? eta -:--:--
#     --------------------------------------- 10.2/472.7 kB ? eta -:--:--
#     --------------------------------------- 10.2/472.7 kB ? eta -:--:--
#    --- ------------------------------------ 41.0/472.7 kB 72.8 kB/s eta 0:00:06
# ...
